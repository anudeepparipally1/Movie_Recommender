# %%
'''<-------------------------------->MOVIE RECOMMENDATION SYSTEM <----------------------->'''
# Out:
# '<-------------------------------->MOVIE RECOMMENDATION SYSTEM <----------------------->'

# %%
#import pandas,numpy and seaborn
import pandas as pd
import numpy as np

# %%
# !pip install modin[ray]

# %%
#reading the credits and movies csv files
credits=pd.read_csv("D:\\ML\\tmdb_5000_credits.csv")
# # movies=pd.read_csv("D:\\ML\\tmdb_5000_movies.csv")
credits
# Out:
#       movie_id                                     title  \
# 0        19995                                    Avatar
# 1          285  Pirates of the Caribbean: At World's End
# 2       206647                                   Spectre
# 3        49026                     The Dark Knight Rises
# 4        49529                               John Carter
# ...        ...                                       ...
# 4798      9367                               El Mariachi
# 4799     72766                                 Newlyweds
# 4800    231617                 Signed, Sealed, Delivered
# 4801    126186                          Shanghai Calling
# 4802     25975                         My Date with Drew
#
#                                                    cast  \
# 0     [{"cast_id": 242, "character": "Jake Sully", "...
# 1     [{"cast_id": 4, "character": "Captain Jack Spa...
# 2     [{"cast_id": 1, "character": "James Bond", "cr...
# ...

# %%
movies=pd.read_csv("C:\\Users\\orsur\\Downloads\\newdata.csv")
movies.head(3)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
#
# ...

# %%
#sample keywords of Avatat movie
movies[movies['original_title']=='Avatar']['keywords'].values
movies.head(3)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
#
# ...

# %%
credits.head(2)
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...

# %%
movies.head(2)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
#
#                                        homepage     id  \
# 0                   http://www.avatarmovie.com/  19995
# 1  http://disney.go.com/disneypictures/pirates/    285
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
#
# ...

# %%
 #mergeing the movies and credits
movies=movies.merge(credits,on='title')

# %%
movies.merge(credits,on='title').shape
# Out:
# (4821, 27)

# %%
movies.head(1)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                       homepage     id  \
# 0  http://www.avatarmovie.com/  19995
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
#
#   original_title                                           overview  \
# 0         Avatar  In the 22nd century, a paraplegic Marine is di...
#
#    popularity                               production_companies  ...  \
# 0  150.437577  [{"name": "Ingenious Film Partners", "id": 289...  ...
#
#                                     spoken_languages    status  \
# 0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
#
#                        tagline   title vote_average vote_count rating  \
# 0  Enter the World of Pandora.  Avatar          7.2      11800   10.0
#
# ...

# %%
# requried columns:
# 1.genres
# 2.id
# 3.keywords
# 4.original title
# 5.overview
# 6.crew and cast

# %%
movies=movies[['id','genres','keywords','original_title','overview','cast','crew','rating']]

# %%
movies.head(1)
# Out:
#       id                                             genres  \
# 0  19995  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                             keywords original_title  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...         Avatar
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
#
#                                                 crew  rating
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...    10.0

# %%
movies.rename(columns = {'cast_x':'cast'}, inplace = True)
movies.rename(columns = {'crew_x':'crew'}, inplace = True)
movies.head(1)
# Out:
#       id                                             genres  \
# 0  19995  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                             keywords original_title  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...         Avatar
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
#
#                                                 crew  rating
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...    10.0

# %%
movies.isnull().sum()
# Out:
# id                0
# genres            0
# keywords          0
# original_title    0
# overview          3
# cast              0
# crew              0
# rating            0
# dtype: int64

# %%
movies.dropna(inplace=True)

# %%
movies.isnull().sum()
# Out:
# id                0
# genres            0
# keywords          0
# original_title    0
# overview          0
# cast              0
# crew              0
# rating            0
# dtype: int64

# %%
movies.duplicated().sum()
# Out:
# 0

# %%
'''keywords from genres
The ast module helps Python applications to process trees of the Python abstract syntax grammar'''
import ast
def convert(obj):
    l=[]
    for i in ast.literal_eval(obj):
        l.append(i['name'])
    return l

# %%
movies['genres']=movies['genres'].apply(convert)

# %%
movies.head()
# Out:
#        id                                         genres  \
# 0   19995  [Action, Adventure, Fantasy, Science Fiction]
# 1     285                   [Adventure, Fantasy, Action]
# 2  206647                     [Action, Adventure, Crime]
# 3   49026               [Action, Crime, Drama, Thriller]
# 4   49529           [Action, Adventure, Science Fiction]
#
#                                             keywords  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...
# 4  [{"id": 818, "name": "based on novel"}, {"id":...
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
# ...

# %%
movies['keywords']=movies['keywords'].apply(convert)

# %%
movies.head(2)
# Out:
#       id                                         genres  \
# 0  19995  [Action, Adventure, Fantasy, Science Fiction]
# 1    285                   [Adventure, Fantasy, Action]
#
#                                             keywords  \
# 0  [culture clash, future, space war, space colon...
# 1  [ocean, drug abuse, exotic island, east india ...
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
#
#                                                 crew  rating
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...    10.0
# ...

# %%
#keywords from 
def convertcast(obj):
    l=[]
    c=0
    for i in ast.literal_eval(obj):
        if c!=3:
            l.append(i['name'])
            c=c+1
        else:
            break
    return l

# %%
movies['cast']=movies['cast'].apply(convertcast)

# %%
movies.head(2)
# Out:
#       id                                         genres  \
# 0  19995  [Action, Adventure, Fantasy, Science Fiction]
# 1    285                   [Adventure, Fantasy, Action]
#
#                                             keywords  \
# 0  [culture clash, future, space war, space colon...
# 1  [ocean, drug abuse, exotic island, east india ...
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
#
#                                                cast  \
# 0  [Sam Worthington, Zoe Saldana, Sigourney Weaver]
# 1     [Johnny Depp, Orlando Bloom, Keira Knightley]
#
#                                                 crew  rating
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...    10.0
# ...

# %%
def convert_director(obj):
    l=[]
    for i in ast.literal_eval(obj):
        if(i['job']=='Director'):
            l.append(i['name'])
            break
    return l

# %%
movies['crew']=movies['crew'].apply(convert_director)

# %%
movies.head(2)
# Out:
#       id                                         genres  \
# 0  19995  [Action, Adventure, Fantasy, Science Fiction]
# 1    285                   [Adventure, Fantasy, Action]
#
#                                             keywords  \
# 0  [culture clash, future, space war, space colon...
# 1  [ocean, drug abuse, exotic island, east india ...
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
#
#                                                cast              crew  rating
# 0  [Sam Worthington, Zoe Saldana, Sigourney Weaver]   [James Cameron]    10.0
# 1     [Johnny Depp, Orlando Bloom, Keira Knightley]  [Gore Verbinski]    10.0

# %%
movies['overview']=movies['overview'].apply(lambda x:x.split())

# %%
movies.head(2)
# Out:
#       id                                         genres  \
# 0  19995  [Action, Adventure, Fantasy, Science Fiction]
# 1    285                   [Adventure, Fantasy, Action]
#
#                                             keywords  \
# 0  [culture clash, future, space war, space colon...
# 1  [ocean, drug abuse, exotic island, east india ...
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
#
#                                             overview  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
#
#                                                cast              crew  rating
# 0  [Sam Worthington, Zoe Saldana, Sigourney Weaver]   [James Cameron]    10.0
# 1     [Johnny Depp, Orlando Bloom, Keira Knightley]  [Gore Verbinski]    10.0

# %%
#removing the space between the names
movies['genres']=movies['genres'].apply(lambda x:[i.replace(" ","") for i in x])
movies['keywords']=movies['keywords'].apply(lambda x:[i.replace(" ","") for i in x])
movies['cast']=movies['cast'].apply(lambda x:[i.replace(" ","") for i in x])
movies['crew']=movies['crew'].apply(lambda x:[i.replace(" ","") for i in x])

# %%
movies.head(2)
# Out:
#       id                                        genres  \
# 0  19995  [Action, Adventure, Fantasy, ScienceFiction]
# 1    285                  [Adventure, Fantasy, Action]
#
#                                             keywords  \
# 0  [cultureclash, future, spacewar, spacecolony, ...
# 1  [ocean, drugabuse, exoticisland, eastindiatrad...
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
#
#                                             overview  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
#
#                                             cast             crew  rating
# 0  [SamWorthington, ZoeSaldana, SigourneyWeaver]   [JamesCameron]    10.0
# 1     [JohnnyDepp, OrlandoBloom, KeiraKnightley]  [GoreVerbinski]    10.0

# %%
movies['tages']=movies['genres']+movies['keywords']+movies['overview']+movies['cast']+movies['crew']

# %%
movies.head(14)
# Out:
#         id                                        genres  \
# 0    19995  [Action, Adventure, Fantasy, ScienceFiction]
# 1      285                  [Adventure, Fantasy, Action]
# 2   206647                    [Action, Adventure, Crime]
# 3    49026              [Action, Crime, Drama, Thriller]
# 4    49529           [Action, Adventure, ScienceFiction]
# 5      559                  [Fantasy, Action, Adventure]
# 6    38757                           [Animation, Family]
# 7    99861           [Action, Adventure, ScienceFiction]
# 8      767                  [Adventure, Fantasy, Family]
# 9   209112                  [Action, Adventure, Fantasy]
# 10    1452  [Adventure, Fantasy, Action, ScienceFiction]
# 11   10764          [Adventure, Action, Thriller, Crime]
# 12      58                  [Adventure, Fantasy, Action]
# 13   57201                  [Action, Adventure, Western]
#
#                                              keywords  \
# ...

# %%
'''required data of id,title,tages'''
new_data=movies[['id',"original_title",'tages','rating']]

# %%
new_data.head(2)
# Out:
#       id                            original_title  \
# 0  19995                                    Avatar
# 1    285  Pirates of the Caribbean: At World's End
#
#                                                tages  rating
# 0  [Action, Adventure, Fantasy, ScienceFiction, c...    10.0
# 1  [Adventure, Fantasy, Action, ocean, drugabuse,...    10.0

# %%
#for testing
new_data[new_data['original_title']=='Avatar']['rating']
# Out:
# 0    10.0
# Name: rating, dtype: float64

# %%
new_data['tages']=new_data['tages'].apply(lambda x:" ".join(x))
# Out:
# <ipython-input-40-c8eb051792d8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data['tages']=new_data['tages'].apply(lambda x:" ".join(x))

# %%
new_data.head(2)
# Out:
#       id                            original_title  \
# 0  19995                                    Avatar
# 1    285  Pirates of the Caribbean: At World's End
#
#                                                tages  rating
# 0  Action Adventure Fantasy ScienceFiction cultur...    10.0
# 1  Adventure Fantasy Action ocean drugabuse exoti...    10.0

# %%
new_data['tages']=new_data['tages'].apply(lambda x:x.lower())
# Out:
# <ipython-input-42-d458013f8954>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data['tages']=new_data['tages'].apply(lambda x:x.lower())

# %%
new_data.head(2)
# Out:
#       id                            original_title  \
# 0  19995                                    Avatar
# 1    285  Pirates of the Caribbean: At World's End
#
#                                                tages  rating
# 0  action adventure fantasy sciencefiction cultur...    10.0
# 1  adventure fantasy action ocean drugabuse exoti...    10.0

# %%
'''T(NLTK) is a platform used for building Python programs that work with
human language data for applying in statistical natural language processing (NLP)'''

import nltk
# Out:
# C:\Users\orsur\anaconda3\lib\site-packages\scipy\__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.4)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "

# %%
'''the Porter stemming algorithm (or 'Porter stemmer') is a process for removing the 
commoner morphological and inflexional endings from words in English'''

    from nltk.stem import PorterStemmer
    stemmer=PorterStemmer()

# %%
def stem(text):
    k=[]
    for i in text.split():
        k.append(stemmer.stem(i))
    return " ".join(k)

# %%
new_data['tages']=new_data['tages'].apply(stem)
# Out:
# <ipython-input-47-361c6988b586>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data['tages']=new_data['tages'].apply(stem)

# %%
new_data.head(2)
# Out:
#       id                            original_title  \
# 0  19995                                    Avatar
# 1    285  Pirates of the Caribbean: At World's End
#
#                                                tages  rating
# 0  action adventur fantasi sciencefict culturecla...    10.0
# 1  adventur fantasi action ocean drugabus exotici...    10.0

# %%
'''Scikit-learn's CountVectorizer is used to convert a collection of text documents to a vector of term/token counts.
It also enables the ​pre-processing of text data prior to generating the vector representation. 
This functionality makes it a highly flexible feature representation module for text.'''

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
cv= CountVectorizer(max_features=5000,stop_words='english')
tv= TfidfVectorizer(max_features=5000,stop_words='english')

# %%
vectors=cv.fit_transform(new_data['tages']).toarray()
vectors2=tv.fit_transform(new_data['tages']).toarray()

# %%
tv.fit_transform(new_data['tages']).toarray().shape
# Out:
# (4806, 5000)

# %%
cv.fit_transform(new_data['tages']).toarray().shape
# Out:
# (4806, 5000)

# %%
#cv.get_feature_names()

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
#Compute cosine similarity between samples in X and Y
similarity=cosine_similarity(vectors)
similarity2=cosine_similarity(vectors2)

# %%
#recommend function is used printing the top 5 related movies
def recommend(movie):
    movie_index=new_data[new_data['original_title']==movie].index[0]
    distance=similarity[movie_index]
    movie_list=sorted(list(enumerate(distance)),reverse=True,key=lambda x:x[1])[1:11]
    r=[]
    m=[]
    rt=[]
    k=1
    for i in movie_list:
        r.append(float(new_data[new_data['original_title']=="{}".format(new_data.iloc[i[0]].original_title)]['rating']))
        m.append(new_data.iloc[i[0]].original_title)
        print("{} ->{}".format(k,new_data.iloc[i[0]].original_title))
        k=k+1
    for i in range(10):
        
        rt.append(r[i])
        
    s = np.array(rt)
    c=1
    j=1
    sort_index = np.argsort(s)
    print("<------------------****Top 5 rated movies among the above 10 movies****------------------>")
    for i in sort_index[::-1]:
        if(c<=5):
            print("{} ->{}".format(j,m[i]))
            c=c+1
            j=j+1

# %%
def recommend2(movie):
    movie_index=new_data[new_data['original_title']==movie].index[0]
    distance=similarity2[movie_index]
    movie_list=sorted(list(enumerate(distance)),reverse=True,key=lambda x:x[1])[1:11]
    r=[]
    m=[]
    rt=[]
    k=1
    for i in movie_list:
        r.append(float(new_data[new_data['original_title']=="{}".format(new_data.iloc[i[0]].original_title)]['rating']))
        m.append(new_data.iloc[i[0]].original_title)
        print("{} ->{}".format(k,new_data.iloc[i[0]].original_title))
        k=k+1
    for i in range(10):
        
        rt.append(r[i])
    print(r)
    s = np.array(rt)
    c=1
    j=1
    tm=[]
    sort_index = np.argsort(s)
    print("<------------------****Top 5 rated movies among the above 10 movies****------------------>")
    for i in sort_index[::-1]:
        if(c<=5):
            tm.append(m[i])
#             print("{} ->{}".format(j,m[i]))
            c=c+1
            j=j+1
    print(tm)

# %% [markdown]
# ### Countvector

# %%
recommend("Avatar")
# Out:
# 1 ->Aliens vs Predator: Requiem
# 2 ->Aliens
# 3 ->Falcon Rising
# 4 ->Independence Day
# 5 ->Titan A.E.
# 6 ->Battle: Los Angeles
# 7 ->Predators
# 8 ->Small Soldiers
# 9 ->Jupiter Ascending
# 10 ->Meet Dave
# <------------------****Top 5 rated movies among the above 10 movies****------------------>
# 1 ->Jupiter Ascending
# 2 ->Falcon Rising
# 3 ->Aliens
# 4 ->Small Soldiers
# 5 ->Predators

# %% [markdown]
# ### Tfidfvector

# %%
recommend2("John Carter")
# Out:
# 1 ->Get Carter
# 2 ->The Marine 4: Moving Target
# 3 ->Spaced Invaders
# 4 ->Meet Dave
# 5 ->My Favorite Martian
# 6 ->Mission to Mars
# 7 ->Raising Cain
# 8 ->Ghosts of Mars
# 9 ->Superman II
# 10 ->Alien³
# [6.0, 7.0, 7.0, 5.0, 5.0, 5.0, 7.0, 7.0, 5.0, 5.0]
# <------------------****Top 5 rated movies among the above 10 movies****------------------>
# ['Ghosts of Mars', 'Raising Cain', 'Spaced Invaders', 'The Marine 4: Moving Target', 'Get Carter']

# %%
## Pickle in Python is primarily used in serializing and deserializing a Python object structure
import pickle

# %%
#The dump() method of the pickle module in Python, converts a Python object hierarchy into a byte stream.
#converting the data into dict
pickle.dump(new_data.to_dict(),open('movies.pkl','wb'))
pickle.dump(similarity,open('similarity.pkl','wb'))

# %%
#converting the data into dict
pickle.dump(new_data.to_dict(),open('updated.pkl','wb'))

# %%
new_data
# Out:
#           id                            original_title  \
# 0      19995                                    Avatar
# 1        285  Pirates of the Caribbean: At World's End
# 2     206647                                   Spectre
# 3      49026                     The Dark Knight Rises
# 4      49529                               John Carter
# ...      ...                                       ...
# 4804    9367                               El Mariachi
# 4805   72766                                 Newlyweds
# 4806  231617                 Signed, Sealed, Delivered
# 4807  126186                          Shanghai Calling
# 4808   25975                         My Date with Drew
#
#                                                   tages  rating
# 0     action adventur fantasi sciencefict culturecla...    10.0
# 1     adventur fantasi action ocean drugabus exotici...    10.0
# 2     action adventur crime spi basedonnovel secreta...    10.0
# ...

# %%
l=[12,3,4,5]

# %%
p=[]
p=l
print(p)
# Out:
# [12, 3, 4, 5]
